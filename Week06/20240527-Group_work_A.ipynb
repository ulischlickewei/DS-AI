# %%
# import all needed packages
import numpy as np
import pandas as pd

import statsmodels.api as sm

import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.stats.outliers_influence \
     import variance_inflation_factor as VIF
from statsmodels.stats.anova import anova_lm

from ISLP import load_data
from ISLP.models import (ModelSpec as MS,
                         summarize,
                         poly)

# suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# In this group work you will work with the `Carseats` dataset provided by the authors of our textbook. Please refer to the [documentation](https://islp.readthedocs.io/en/latest/datasets/Carseats.html) for additional information on the dataset.

# %%
Carseats = load_data('Carseats')
Carseats
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %% [markdown]
# ## Task 1: Explore the dataset.
# This includes activities such as:
# - Compute summary statistics for the variables
# - Create some interesting visualizations
# - Analyze correlations between the variables (focussing specifically on the variable `Sales` which we want to predict in the task below)
# - ...
#
# Comment on your findings.

# %%
# your code here

# %% [markdown]
# *your findings here*

# %% [markdown]
# ## Task 2: Create a regression model.
# Build a regression model to predict the variable `Sales`. Start with a simple linear regression model based on the unique predictor `Price` (= Price company charges for car seats at each site). Then extend your model iteratively by adding further predictors to obtain more accurate predictions. Explain how you choose which variables to add and decide on a final model.

# %%
# your code here

# %% [markdown]
# *your findings here*

# %% [markdown]
# ## Task 3: Analyze your model.
# Evaluate the quality of your model and create some diagnostic plots to identify potential problems.

# %%
# your code here

# %% [markdown]
# *your findings here*
