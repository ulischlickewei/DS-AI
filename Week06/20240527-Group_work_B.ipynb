# %% [markdown]
# ## Step 0) Prepare environment and load data

# %%
# import all needed packages
import numpy as np
import pandas as pd

import statsmodels.api as sm

import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.stats.outliers_influence \
     import variance_inflation_factor as VIF
from statsmodels.stats.anova import anova_lm

from ISLP import load_data
from ISLP.models import (ModelSpec as MS,
                         summarize,
                         poly)

# suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# In this group work you will work with the `Boston` dataset provided by the authors of our textbook. Please refer to the [documentation](https://islp.readthedocs.io/en/latest/datasets/Boston.html) for additional information on the dataset.

# %%
Boston = load_data('Boston')
Boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %% [markdown]
# ## Task 1: Explore the dataset.
# This includes activities such as:
# - Compute summary statistics for the variables
# - Create some interesting visualizations
# - Analyze correlations between the variables (focussing specifically on the variable `medv` which we want to predict in the task below)
# - ...
#
# Comment on your findings.

# %%
# your code here

# %% [markdown]
# *your findings here*

# %% [markdown]
# ## Task 2: Create a regression model.
# Build a regression model to predict the variable `medv`. Start with a simple linear regression model based on the unique predictor `lstat` (= precent of households with low socioeconomic status). Then extend your model iteratively by adding further predictors to obtain more accurate predictions. Explain how you choose which variables to add and decide on a final model.

# %%
# your code here

# %% [markdown]
# *your findings here*

# %% [markdown]
# ## Task 3: Analyze your model.
# Evaluate the quality of your model and create some diagnostic plots to identify potential problems.

# %%
# your code here

# %% [markdown]
# *your findings here*
